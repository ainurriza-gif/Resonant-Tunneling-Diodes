# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
import itertools
import os

# %%
'''
Data hasil simulasi sebelumnya tersedia online di drive dengan link:
https://drive.google.com/drive/folders/1-uuTJ4ULnKGOQ8KZQfYpzcc94t_4Xu4A?usp=sharing
'''

# !gdown --folder --id 1-uuTJ4ULnKGOQ8KZQfYpzcc94t_4Xu4A -O /
os.chdir('/TMM Validation data')

os.listdir()
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Retrieving folder contents
# Processing file 19fM6IwLh3ZQKO9EdXe1AmIFIuDJ9neBj validasipenghalangeckart_analitik.npz
# Processing file 1wiuSnvBMFpysaoJGAHVBYTphpwXzoswj validasipenghalangeckart_dx0.1.npz
# Processing file 1OAcBDr0u09R-vAWK1_PAA7fhDbk5ejzr validasipenghalangeckart_dx0.01.npz
# Processing file 1ogH_etST13mS8QC8lJl5Ezrr9nwMtRkv validasipenghalangeckart_dx0.001.npz
# Processing file 1q1WQZaBzX9ZEC2EByK-wtdbMCixh6PGb validasipenghalangganda_analitik.npz
# Processing file 1yVnTluyCPrv9hL9kEOr2M45tjTwlFXWG validasipenghalangganda_dx0.1.npz
# Processing file 1ggg-YlmQjcDnJtM_wBfn9ChSv4ES6OAu validasipenghalangganda_dx0.01.npz
# Processing file 1VjDRoC7IgrQn0qlcVuhpdTu7bKEL793Z validasipenghalangganda_dx0.001.npz
# Processing file 1X7JvFVgNNhri2zu1qEyZ3mLe2D9Hlihw validasipenghalangtunggal_analitik.npz
# Processing file 1kcWCJhTlEP4WU67zq3EO-XS6RFYFV80q validasipenghalangtunggal_dx0.1.npz
# Processing file 1Ms_2oWGfHhPssVrQ2fryUMsapTlqMnTN validasipenghalangtunggal_dx0.01.npz
# Processing file 1GcM0Hm4C60zCSJYGS8LPvGazAjK4eORt validasipenghalangtunggal_dx0.001.npz
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=19fM6IwLh3ZQKO9EdXe1AmIFIuDJ9neBj
# To: /TMM Validation data/validasipenghalangeckart_analitik.npz
# 100% 3.73k/3.73k [00:00<00:00, 14.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1wiuSnvBMFpysaoJGAHVBYTphpwXzoswj
# To: /TMM Validation data/validasipenghalangeckart_dx0.1.npz
# 100% 3.73k/3.73k [00:00<00:00, 15.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OAcBDr0u09R-vAWK1_PAA7fhDbk5ejzr
# To: /TMM Validation data/validasipenghalangeckart_dx0.01.npz
# 100% 3.73k/3.73k [00:00<00:00, 12.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ogH_etST13mS8QC8lJl5Ezrr9nwMtRkv
# To: /TMM Validation data/validasipenghalangeckart_dx0.001.npz
# 100% 3.73k/3.73k [00:00<00:00, 17.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1q1WQZaBzX9ZEC2EByK-wtdbMCixh6PGb
# To: /TMM Validation data/validasipenghalangganda_analitik.npz
# 100% 3.72k/3.72k [00:00<00:00, 18.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1yVnTluyCPrv9hL9kEOr2M45tjTwlFXWG
# To: /TMM Validation data/validasipenghalangganda_dx0.1.npz
# 100% 3.72k/3.72k [00:00<00:00, 18.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ggg-YlmQjcDnJtM_wBfn9ChSv4ES6OAu
# To: /TMM Validation data/validasipenghalangganda_dx0.01.npz
# 100% 3.72k/3.72k [00:00<00:00, 18.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VjDRoC7IgrQn0qlcVuhpdTu7bKEL793Z
# To: /TMM Validation data/validasipenghalangganda_dx0.001.npz
# 100% 3.72k/3.72k [00:00<00:00, 14.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1X7JvFVgNNhri2zu1qEyZ3mLe2D9Hlihw
# To: /TMM Validation data/validasipenghalangtunggal_analitik.npz
# 100% 3.72k/3.72k [00:00<00:00, 15.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1kcWCJhTlEP4WU67zq3EO-XS6RFYFV80q
# To: /TMM Validation data/validasipenghalangtunggal_dx0.1.npz
# 100% 3.72k/3.72k [00:00<00:00, 17.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ms_2oWGfHhPssVrQ2fryUMsapTlqMnTN
# To: /TMM Validation data/validasipenghalangtunggal_dx0.01.npz
# 100% 3.72k/3.72k [00:00<00:00, 18.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1GcM0Hm4C60zCSJYGS8LPvGazAjK4eORt
# To: /TMM Validation data/validasipenghalangtunggal_dx0.001.npz
# 100% 3.72k/3.72k [00:00<00:00, 17.1MB/s]
# Download completed
# ['validasipenghalangeckart_analitik.npz',
#  'validasipenghalangeckart_dx0.01.npz',
#  'validasipenghalangganda_dx0.1.npz',
#  'validasipenghalangtunggal_analitik.npz',
#  'validasipenghalangeckart_dx0.001.npz',
#  'validasipenghalangganda_dx0.01.npz',
#  'validasipenghalangganda_dx0.001.npz',
#  'validasipenghalangtunggal_dx0.1.npz',
#  'validasipenghalangtunggal_dx0.01.npz',
#  'validasipenghalangganda_analitik.npz',
#  'validasipenghalangtunggal_dx0.001.npz',
#  'validasipenghalangeckart_dx0.1.npz']

# %% [markdown]
# #Potensial Penghalang Tunggal

# %%
import time
start = time.time()

# %%
#Satuan sumbu x dalam nm
xmin = - 10
xmax = 20
dx = 0.001
nx = int((xmax-xmin)/dx) + 1
x = np.linspace(xmin, xmax, nx)
print(nx)
# Out:
# 30001

# %%
#Definisi bentuk potensial (eV)
L = 10  #nm
V = 1   #eV

def potensial(x):
  if 0 <= x < L:
    return V
  if x < 0 :
    return 0
  if x >= L :
    return 0

pot = np.vectorize(potensial)(x)

# %%
#Plot
plt.figure(figsize=(8, 6))
plt.plot(x, pot, color='black')

plt.xlabel("x [nm]", fontsize = 15)
plt.ylabel("Potential Energy [eV]", fontsize = 15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)

plt.show()

# %%
#Massa efektif dalam satuan me (massa elektron)
def mass_eff(x):
  return 1

mass_eff = np.vectorize(mass_eff)(x)

# %%
#s adalah koefisien untuk merubah agar satuan k menjadi nm-1
hbar      = 1.054571817e-34     #Js
me        = 9.109534e-31        #Kg
eV_to_J   = 1.602176634e-19     #Merubah eV menjadi Joule
nm_to_m_2 = 1e-18               #agar satuan k menjadi nm-1
s = 2*me*eV_to_J*nm_to_m_2/(hbar**2)

"""Bilangan gelombang"""
@njit
def km(E, Vm, mfm):
  #Atasi nilai k=0 untuk E=V
  if E == Vm:
    Ec = E + 1e-15
    k  = np.sqrt(s*mfm*(Ec-Vm) + 0j)
  else:
    k  = np.sqrt(s*mfm*(E-Vm) + 0j)
  return k

"""Koefisien delta"""
@njit
def delta(E, Vm, mfm, Vm1, mfm1):
  k0 = km(E, Vm, mfm)
  k1 = km(E, Vm1, mfm1)
  delta1 = (k1/k0)*(mfm/mfm1)
  return delta1

"""Matriks Syarat Batas (D)"""
@njit
def D(E, Vm, mfm, Vm1, mfm1):
  delta1 = delta(E, Vm, mfm, Vm1, mfm1)
  a = 0.5*(1 + delta1)
  b = 0.5*(1 - delta1)
  c = b
  d = a
  nilai_D = np.array([[a, b], [c, d]])
  return nilai_D

"""Matriks Propagasi (P)"""
@njit
def P(E, Vm, mfm, dm):
  a = np.exp(-1j * km(E, Vm, mfm) * dm)
  b = 0
  c = 0
  d = np.exp( 1j * km(E, Vm, mfm) * dm)
  nilai_P = np.array([[a, b], [c, d]])
  return nilai_P

# %%
"""Perhitungan Koefisien Transmisi """
@njit
def nilai(E):
  M = np.identity(2, dtype=np.complex128)

  #Matriks Syarat Batas Awal
  M = M @ D(E, pot[0], mass_eff[0], pot[1], mass_eff[1])

  for i in range(1, nx-1):
    matriks_P = P(E, pot[i], mass_eff[i], dx)
    matriks_D = D(E, pot[i], mass_eff[i], pot[i+1], mass_eff[i+1])
    M= M @ matriks_P @ matriks_D

  #Nilai koefisien trasmisi
  A = np.abs(M[0,0])
  rasio_meff = mass_eff[0]/mass_eff[-1]
  kR   = km(E, pot[-1], mass_eff[-1])
  kL   = km(E, pot[0], mass_eff[0])
  rasio_koef = (np.abs(kR))/(np.abs(kL))
  T = rasio_meff * rasio_koef / (A*A)

  return T

# %%
E = np.arange(0.9, 1.1, 0.001)
E = E[E !=1]

# %%
nilai_transmisi = [nilai(i) for i in E]

# %%
#Analitik
V0 = V

#Fungsi koefisien transmisi analitik
def transmisi_analitik(E):
  if E >= V0:
    if E == V0:
      E = E + 1e-15
    k1 = np.sqrt(s * E)
    k2 = np.sqrt(s * (E - V0))
    T = 1 / (1 + (V0**2 / (4 * E * (E - V0))) * np.sin(k2 * L)**2)
  if E < V0:
    k1 = np.sqrt(s * E)
    kappa = np.sqrt(s * (V0 - E))
    T = 1 / (1 + (V0**2 / (4 * E * (V0 - E))) * np.sinh(kappa * L)**2)
  return T

T_analitik = [transmisi_analitik(i) for i in E]

# %%
#save npz
filename = f"validasipenghalangtunggal_dx{dx}.npz"
np.savez(filename, E=E, nilai_transmisi=nilai_transmisi)

filename1 = f"validasipenghalangtunggal_analitik.npz"
np.savez(filename1, E=E, nilai_transmisi=T_analitik)

# %%
end = time.time()
print(f"\nTotal waktu eksekusi: {end - start:.5f} detik")
# Out:
# Total waktu eksekusi: 11.44192 detik

# %% [markdown]
# #Validasi Potensial Penghalang Tunggal

# %%
# Load data dari file npz
dx = [0.1, 0.01, 0.001]
for i in dx:
  dx = i
  filename = f"validasipenghalangtunggal_dx{dx}.npz"
  data = np.load(filename)
  variable = {f"{var}_dx{str(dx).replace('.', '_')}": data[var] for var in ['E', 'nilai_transmisi']}
  globals().update(variable)

# Load data analitik
filename = f"validasipenghalangtunggal_analitik.npz"
data = np.load(filename)
variable = {f"{var}": data[var] for var in ['E', 'nilai_transmisi']}
globals().update(variable)

# %%
E = E_dx0_1
T1 = nilai_transmisi_dx0_1
T2 = nilai_transmisi_dx0_01
T3 = nilai_transmisi_dx0_001
T_analitik = nilai_transmisi

# %%
colors = itertools.cycle(['r', 'g', 'b', 'm', 'y', 'k'])
linestyles = itertools.cycle(['-', '--', '-.', ':'])

plt.figure(figsize=(8, 6))
plt.plot(E, T1, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.1$     nm')
plt.plot(E, T2, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.01$   nm')
plt.plot(E, T3, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.001$ nm')
plt.plot(E, T_analitik, color='m', linestyle=':', label='Analytic')

#plt.title("Single Barrier Potential", fontsize=10)
plt.xlabel("Electron Energy [eV]", fontsize=15)
plt.ylabel("Transmission Coefficient", fontsize=15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)
plt.legend(labelspacing=0.2, loc = 'upper left', fontsize=15)

plt.show()

# %%
colors = itertools.cycle(['r', 'g', 'b', 'm', 'y', 'k'])
linestyles = itertools.cycle(['-', '--', '-.', ':'])

#Ralat
errT1 = np.abs(np.array(T1) - np.array(T_analitik))*100/np.array(T_analitik)
errT2 = np.abs(np.array(T2) - np.array(T_analitik))*100/np.array(T_analitik)
errT3 = np.abs(np.array(T3) - np.array(T_analitik))*100/np.array(T_analitik)

plt.figure(figsize=(8, 6))
plt.plot(E, errT1, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.1$     nm', alpha = 0.8)
plt.plot(E, errT2, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.01$   nm', alpha = 0.8)
plt.plot(E, errT3, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.001$ nm', alpha = 0.8)

plt.xlabel("Electron Energy [eV]", fontsize = 15)
plt.ylabel("Relative Error of The Transmission Coeff. [%]" , fontsize = 15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)
plt.legend(labelspacing=0.2, loc='upper left', fontsize=15)#, frameon = False)
plt.ylim(5e-15, 5e-8)
plt.yscale('log')

plt.show()

# %%
'''Error Relatif Rata Rata'''
ER1 = np.mean(errT1)
ER2 = np.mean(errT2)
ER3 = np.mean(errT3)
print(f"{ER1} %, {ER2} %, {ER3} %")
# Out:
# 1.2445604083705552e-12 %, 1.2302367536802463e-11 %, 1.3961972020799547e-10 %

# %%
#Simpan Data
import pandas as pd

df = pd.DataFrame({
    "E (eV)": E,
    "T_Analitik": T_analitik,
    "T_dx0.1": T1,
    "T_dx0.01": T2,
    "T_dx0.001": T3,
    "Err_dx0.1 (%)": errT1,
    "Err_dx0.01 (%)": errT2,
    "Err_dx0.001 (%)": errT3
})

df.to_excel("single_barrier_data(errorTMM).xlsx", index=False)

# %% [markdown]
# #Potensial Penghalang Ganda

# %%
import time
start = time.time()

# %%
#Validasi Potensial Penghalang Ganda
#Satuan dalam nm untuk dimensi x
left = 9
b = 4
a = 4
right = 9
#Satuan sumbu x dalam nm
xmin = - left - a
xmax = b + a + right
dx = 0.1
nx = int((xmax-xmin)/dx) + 1
x = np.linspace(xmin, xmax, nx)
print(nx)
# Out:
# 301

# %%
#Definisi bentuk potensial (eV)
V = 1   #eV

def potensial(x):
  if -a <= x < 0:
    return V
  if b <= x < b+a:
    return V
  else:
    return 0

pot = np.vectorize(potensial)(x)

# %%
#Plot
plt.figure(figsize=(8, 6))
plt.plot(x, pot, color='black')

plt.xlabel("x [nm]", fontsize = 15)
plt.ylabel("Potential Energy [eV]", fontsize = 15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)

plt.show()

# %%
#Massa efektif dalam satuan me (massa elektron)
def mass_eff(x):
  return 1

mass_eff = np.vectorize(mass_eff)(x)

# %%
#s adalah koefisien untuk merubah agar satuan k menjadi nm-1
hbar      = 1.054571817e-34     #Js
me        = 9.109534e-31        #Kg
eV_to_J   = 1.602176634e-19     #Merubah eV menjadi Joule
nm_to_m_2 = 1e-18               #agar satuan k menjadi nm-1
s = 2*me*eV_to_J*nm_to_m_2/(hbar**2)

"""Bilangan gelombang"""
@njit
def km(E, Vm, mfm):
  #Atasi nilai k=0 untuk E=V
  if E == Vm:
    Ec = E + 1e-15
    k  = np.sqrt(s*mfm*(Ec-Vm) + 0j)
  else:
    k  = np.sqrt(s*mfm*(E-Vm) + 0j)
  return k

"""Koefisien delta"""
@njit
def delta(E, Vm, mfm, Vm1, mfm1):
  k0 = km(E, Vm, mfm)
  k1 = km(E, Vm1, mfm1)
  delta1 = (k1/k0)*(mfm/mfm1)
  return delta1

"""Matriks Syarat Batas (D)"""
@njit
def D(E, Vm, mfm, Vm1, mfm1):
  delta1 = delta(E, Vm, mfm, Vm1, mfm1)
  a = 0.5*(1 + delta1)
  b = 0.5*(1 - delta1)
  c = b
  d = a
  nilai_D = np.array([[a, b], [c, d]])
  return nilai_D

"""Matriks Propagasi (P)"""
@njit
def P(E, Vm, mfm, dm):
  a = np.exp(-1j * km(E, Vm, mfm) * dm)
  b = 0
  c = 0
  d = np.exp( 1j * km(E, Vm, mfm) * dm)
  nilai_P = np.array([[a, b], [c, d]])
  return nilai_P

# %%
"""Perhitungan Koefisien Transmisi """
@njit
def nilai(E):
  M = np.identity(2, dtype=np.complex128)

  #Matriks Syarat Batas Awal
  M = M @ D(E, pot[0], mass_eff[0], pot[1], mass_eff[1])

  for i in range(1, nx-1):
    matriks_P = P(E, pot[i], mass_eff[i], dx)
    matriks_D = D(E, pot[i], mass_eff[i], pot[i+1], mass_eff[i+1])
    M= M @ matriks_P @ matriks_D

  #Nilai koefisien trasmisi
  A = np.abs(M[0,0])
  rasio_meff = mass_eff[0]/mass_eff[-1]
  kR   = km(E, pot[-1], mass_eff[-1])
  kL   = km(E, pot[0], mass_eff[0])
  rasio_koef = (np.abs(kR))/(np.abs(kL))
  T = rasio_meff * rasio_koef / (A*A)

  return T

# %%
E = np.arange(0.9, 1.1, 0.001)
E = E[E !=1]
nilai_transmisi = [nilai(i) for i in E]

# %%
#analitik
V0 = V

def transmisi_analitik(E):
  if (E == V0).any():
    E = E + 1e-15

  k1 = np.sqrt(s * E)
  k2 = np.sqrt(s * (V0 - E) + 0j)

  alpha = k1**2 - k2**2
  beta = k1**2 + k2**2
  gamma = k1 * k2

  C1 = 4 * gamma**2 * np.cosh(2 * a * k2) * np.cos(b * k1) - 2 * alpha * gamma * np.sinh(2 * a * k2) * np.sin(b * k1)
  C2 = alpha**2 * np.cosh(2 * a * k2) * np.sin(b * k1) - 2 * alpha * gamma * np.sinh(2 * a * k2) * np.cos(b * k1) - beta**2 * np.sin(b * k1)
  C3 = 4 * gamma**2

  T = (C3**2) / (C1**2 + C2**2)
  T = np.abs(T)
  return T

T_analitik = transmisi_analitik(E)

# %%
#save npz
filename = f"validasipenghalangganda_dx{dx}.npz"
np.savez(filename, E=E, nilai_transmisi=nilai_transmisi)

filename1 = f"validasipenghalangganda_analitik.npz"
np.savez(filename1, E=E, nilai_transmisi=T_analitik)

# %%
end = time.time()
print(f"\nTotal waktu eksekusi: {end - start:.5f} detik")
# Out:
# Total waktu eksekusi: 3.78157 detik

# %% [markdown]
# #Validasi Potensial Penghalang Ganda

# %%
# Load data dari file npz
dx = [0.1, 0.01, 0.001]
for i in dx:
  dx = i
  filename = f"validasipenghalangganda_dx{dx}.npz"
  data = np.load(filename)
  variable = {f"ganda_{var}_dx{str(dx).replace('.', '_')}": data[var] for var in ['E', 'nilai_transmisi']}
  globals().update(variable)

# Load data analitik
filename = f"validasipenghalangganda_analitik.npz"
data = np.load(filename)
variable = {f"ganda_{var}": data[var] for var in ['E', 'nilai_transmisi']}
globals().update(variable)

# %%
E_ganda = ganda_E_dx0_1
T1_ganda = ganda_nilai_transmisi_dx0_1
T2_ganda = ganda_nilai_transmisi_dx0_01
T3_ganda = ganda_nilai_transmisi_dx0_001
T_ganda = ganda_nilai_transmisi

# %%
colors = itertools.cycle(['r', 'g', 'b', 'm', 'y', 'k'])
linestyles = itertools.cycle(['-', '--', '-.', ':'])

plt.figure(figsize=(8, 6))
plt.plot(E_ganda, T1_ganda, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.1$     nm')
plt.plot(E_ganda, T2_ganda, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.01$   nm')
plt.plot(E_ganda, T3_ganda, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.001$ nm')
plt.plot(E_ganda, T_ganda, color='m', linestyle=':', label='Analytic')

#plt.title("Double Barrier Potential", fontsize=10)
plt.xlabel("Electron Energy [eV]", fontsize = 15)
plt.ylabel("Transmission Coefficient", fontsize = 15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)
plt.legend(labelspacing=0.2, loc = 'upper left', fontsize = 15)

plt.show()

# %%
colors = itertools.cycle(['r', 'g', 'b', 'm', 'y', 'k'])
linestyles = itertools.cycle(['-', '--', '-.', ':'])

#Ralat
errT1_ganda = np.abs(np.array(T1_ganda) - np.array(T_ganda))*100/np.array(T_ganda)
errT2_ganda = np.abs(np.array(T2_ganda) - np.array(T_ganda))*100/np.array(T_ganda)
errT3_ganda = np.abs(np.array(T3_ganda) - np.array(T_ganda))*100/np.array(T_ganda)

plt.figure(figsize=(8, 6))
plt.plot(E_ganda, errT1_ganda, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.1$     nm')
plt.plot(E_ganda, errT2_ganda, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.01$   nm')
plt.plot(E_ganda, errT3_ganda, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.001$ nm')

plt.xlabel("Electron Energy (eV)", fontsize = 15)
plt.ylabel("Relative Error of The Transmission Coeff. [%]" , fontsize = 15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)
plt.legend(labelspacing=0.2, loc='upper left', fontsize = 15)#, frameon = False)
plt.ylim(5e-15, 5e-8)
plt.yscale('log')

plt.show()

# %%
'''Error Relatif Rata Rata'''
ER1_ganda = np.mean(errT1_ganda)
ER2_ganda = np.mean(errT2_ganda)
ER3_ganda = np.mean(errT3_ganda)
print(f"{ER1_ganda} %, {ER2_ganda} %, {ER3_ganda} %")
# Out:
# 1.6483872267853294e-12 %, 1.3090770737794599e-11 %, 1.4121933038465265e-10 %

# %%
#Simpan Data
import pandas as pd

df = pd.DataFrame({
    "E (eV)": E_ganda,
    "T_Analitik": T_ganda,
    "T_dx0.1": T1_ganda,
    "T_dx0.01": T2_ganda,
    "T_dx0.001": T3_ganda,
    "Err_dx0.1 (%)": errT1_ganda,
    "Err_dx0.01 (%)": errT2_ganda,
    "Err_dx0.001 (%)": errT3_ganda
})

df.to_excel("double_barrier_data(errorTMM).xlsx", index=False)

# %% [markdown]
# #Potensial Penghalang Eckart

# %%
import time
start = time.time()

# %%
#Validasi Potensial Penghalang Eckart
#Satuan sumbu x dalam nm
xmin = -15
xmax = 15
dx = 0.001
nx = int((xmax-xmin)/dx) + 1
x = np.linspace(xmin, xmax, nx)
print(nx)
# Out:
# 30001

# %%
#Definisi bentuk potensial eckart(eV)
l0  = 1     #nm
V0  = 1     #eV
c   = 1     #konstanta potenial eckart

def potensial(x):
  kons1 = np.exp(x/l0)
  V = V0 * (1-((1 - kons1)/(1 + c*kons1))**2)
  return V

pot = np.vectorize(potensial)(x)

# %%
#Plot
plt.figure(figsize=(8, 6))
plt.plot(x, pot, color='k', lw=2)
#plt.title(f"Graph Symmetric Eckart Barrier Potential", fontsize=10)
plt.xlabel("x [nm]", fontsize = 15)
plt.ylabel("Potential Energy [eV]", fontsize = 15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)

plt.show()

# %%
#Massa efektif dalam satuan me (massa elektron)
def mass_eff(x):
  return 1

mass_eff = np.vectorize(mass_eff)(x)

# %%
#s adalah koefisien untuk merubah agar satuan k menjadi nm-1
hbar      = 1.054571817e-34     #Js
me        = 9.109534e-31        #Kg
eV_to_J   = 1.602176634e-19     #Merubah eV menjadi Joule
nm_to_m_2 = 1e-18               #agar satuan k menjadi nm-1
s = 2*me*eV_to_J*nm_to_m_2/(hbar**2)

"""Bilangan gelombang"""
@njit
def km(E, Vm, mfm):
  #Atasi nilai k=0 untuk E=V
  if E == Vm:
    Ec = E + 1e-15
    k  = np.sqrt(s*mfm*(Ec-Vm) + 0j)
  else:
    k  = np.sqrt(s*mfm*(E-Vm) + 0j)
  return k

"""Koefisien delta"""
@njit
def delta(E, Vm, mfm, Vm1, mfm1):
  k0 = km(E, Vm, mfm)
  k1 = km(E, Vm1, mfm1)
  delta1 = (k1/k0)*(mfm/mfm1)
  return delta1

"""Matriks Syarat Batas (D)"""
@njit
def D(E, Vm, mfm, Vm1, mfm1):
  delta1 = delta(E, Vm, mfm, Vm1, mfm1)
  a = 0.5*(1 + delta1)
  b = 0.5*(1 - delta1)
  c = b
  d = a
  nilai_D = np.array([[a, b], [c, d]])
  return nilai_D

"""Matriks Propagasi (P)"""
@njit
def P(E, Vm, mfm, dm):
  a = np.exp(-1j * km(E, Vm, mfm) * dm)
  b = 0
  c = 0
  d = np.exp( 1j * km(E, Vm, mfm) * dm)
  nilai_P = np.array([[a, b], [c, d]])
  return nilai_P

# %%
"""Perhitungan Koefisien Transmisi """
@njit
def nilai(E):
  M = np.identity(2, dtype=np.complex128)

  #Matriks Syarat Batas Awal
  M = M @ D(E, pot[0], mass_eff[0], pot[1], mass_eff[1])

  for i in range(1, nx-1):
    matriks_P = P(E, pot[i], mass_eff[i], dx)
    matriks_D = D(E, pot[i], mass_eff[i], pot[i+1], mass_eff[i+1])
    M= M @ matriks_P @ matriks_D

  #Nilai koefisien trasmisi
  A = np.abs(M[0,0])
  rasio_meff = mass_eff[0]/mass_eff[-1]
  kR   = km(E, pot[-1], mass_eff[-1])
  kL   = km(E, pot[0], mass_eff[0])
  rasio_koef = (np.abs(kR))/(np.abs(kL))
  T = rasio_meff * rasio_koef / (A*A)

  return T

# %%
E = np.arange(0.9, 1.1, 0.001)
nilai_transmisi = [nilai(i) for i in E]

# %%
#analitik
def transmisi_analitik(E):
  E     = E*eV_to_J
  V     = V0*eV_to_J
  l     = l0*1e-9
  delta = hbar**2/(2*me*l**2)
  cquad = c*c
  bquad = 1/cquad
  fquad = E/delta
  qquad = V/delta
  b     = np.sqrt(bquad)
  f     = np.sqrt(fquad)
  q     = np.sqrt(qquad)
  s     = np.sqrt(fquad + (bquad-1)*qquad)
  g     = np.sqrt(qquad*(b+1)**2 - (1/4))

  c1 = np.sinh(2*np.pi*f)
  c2 = np.sinh(2*np.pi*s)
  c3 = np.cosh(np.pi*(f+s+g))
  c4 = np.cosh(np.pi*(f+s-g))

  T = c1*c2/(c3*c4)

  return T

T_analitik = transmisi_analitik(E)

# %%
#save npz
filename = f"validasipenghalangeckart_dx{dx}.npz"
np.savez(filename, E=E, nilai_transmisi=nilai_transmisi)

filename1 = f"validasipenghalangeckart_analitik.npz"
np.savez(filename1, E=E, nilai_transmisi=T_analitik)

# %%
end = time.time()
print(f"\nTotal waktu eksekusi: {end - start:.5f} detik")
# Out:
# Total waktu eksekusi: 11.71408 detik

# %% [markdown]
# #Validasi Potensial Penghalang Eckart

# %%
# Load data dari file npz
dx = [0.1, 0.01, 0.001]
for i in dx:
  dx = i
  filename = f"validasipenghalangeckart_dx{dx}.npz"
  data = np.load(filename)
  variable = {f"eckart_{var}_dx{str(dx).replace('.', '_')}": data[var] for var in ['E', 'nilai_transmisi']}
  globals().update(variable)

# Load data analitik
filename = f"validasipenghalangeckart_analitik.npz"
data = np.load(filename)
variable = {f"eckart_{var}": data[var] for var in ['E', 'nilai_transmisi']}
globals().update(variable)

# %%
E_eckart   = eckart_E_dx0_1
T1_eckart  = eckart_nilai_transmisi_dx0_1
T2_eckart  = eckart_nilai_transmisi_dx0_01
T3_eckart  = eckart_nilai_transmisi_dx0_001
T_eckart   = eckart_nilai_transmisi

# %%
colors = itertools.cycle(['r', 'g', 'b', 'm', 'y', 'k'])
linestyles = itertools.cycle(['-', '--', '-.', ':'])

plt.figure(figsize=(8, 6))
plt.plot(E_eckart, T1_eckart, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.1$     nm')
plt.plot(E_eckart, T2_eckart, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.01$   nm')
plt.plot(E_eckart, T3_eckart, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.001$ nm')
plt.plot(E_eckart, T_eckart, color='m', linestyle=':', label='Analytic')

#plt.title("Symmetric Eckart Barrier Potential", fontsize=10)
plt.xlabel("Electron Energy [eV]", fontsize=15)
plt.ylabel("Transmission Coefficient", fontsize=15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)
plt.legend(labelspacing=0.2, loc = 'upper left', fontsize=15)

plt.show()

# %%
colors = itertools.cycle(['r', 'g', 'b', 'm', 'y', 'k'])
linestyles = itertools.cycle(['-', '--', '-.', ':'])

#Ralat
errT1_eckart = np.abs(np.array(T1_eckart) - np.array(T_eckart))*100/np.array(T_eckart)
errT2_eckart = np.abs(np.array(T2_eckart) - np.array(T_eckart))*100/np.array(T_eckart)
errT3_eckart = np.abs(np.array(T3_eckart) - np.array(T_eckart))*100/np.array(T_eckart)

plt.figure(figsize=(8, 6))
plt.plot(E_eckart, errT1_eckart, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.1$     nm')
plt.plot(E_eckart, errT2_eckart, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.01$   nm')
plt.plot(E_eckart, errT3_eckart, color=next(colors), linestyle=next(linestyles), label=r'$\Delta$$x=0.001$ nm')

#plt.title("Absolute Error in The Symmetric Eckart Barrier Potential", fontsize=10)
plt.xlabel("Electron Energy [eV]", fontsize = 15)
plt.ylabel("Relative Error of The Transmission Coeff. [%]" , fontsize = 15)

ax = plt.gca()
ax.tick_params(top=True, right=True, which='both')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.grid(color = 'black', linestyle = '--', linewidth = 0.9, alpha = 0.1)
plt.legend(labelspacing=0.2, loc='best', fontsize = 14)#, frameon = False)
plt.yscale('log')

plt.show()

# %%
'''Error Relatif Rata Rata'''
ER1_eckart = np.mean(errT1_eckart)
ER2_eckart = np.mean(errT2_eckart)
ER3_eckart = np.mean(errT3_eckart)
print(f"{ER1_eckart} %, {ER2_eckart} %, {ER3_eckart} %")
# Out:
# 0.3092130597135012 %, 0.0030876453441820786 %, 3.141924552995359e-05 %

# %%
#Simpan Data
import pandas as pd

df = pd.DataFrame({
    "E (eV)": E_eckart,
    "T_Analitik": T_eckart,
    "T_dx0.1": T1_eckart,
    "T_dx0.01": T2_eckart,
    "T_dx0.001": T3_eckart,
    "Err_dx0.1 (%)": errT1_eckart,
    "Err_dx0.01 (%)": errT2_eckart,
    "Err_dx0.001 (%)": errT3_eckart
})

df.to_excel("eckart_barrier_data(errorTMM).xlsx", index=False)
